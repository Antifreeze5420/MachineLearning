# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import colors

# %%
titanic_data = pd.read_csv(r'C:/Users/incor/TFOD/titanic.csv')

# %%
titanic_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare  ... Embarked WikiId  \
# 0      0         A/5 21171   7.2500  ...        S  691.0
# 1      0          PC 17599  71.2833  ...        C   90.0
# 2      0  STON/O2. 3101282   7.9250  ...        S  865.0
# 3      0            113803  53.1000  ...        S  127.0
# ...

# %%
titanic_pclass1 = (titanic_data.Pclass==1)

# %%
titanic_pclass1
# Out:
# 0       False
# 1        True
# 2       False
# 3        True
# 4       False
#         ...
# 1304    False
# 1305     True
# 1306    False
# 1307    False
# 1308    False
# Name: Pclass, Length: 1309, dtype: bool

# %%
    titanic_pclass1_data = titanic_data[titanic_pclass1]

# %%
titanic_pclass1_data.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2       1.0       1
# 3             4       1.0       1
# 6             7       0.0       1
# 11           12       1.0       1
# 23           24       1.0       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 23                       Sloper, Mr. William Thompson    male  28.0      0
#
#     Parch    Ticket     Fare  ... Embarked WikiId  \
# 1       0  PC 17599  71.2833  ...        C   90.0
# 3       0    113803  53.1000  ...        S  127.0
# 6       0     17463  51.8625  ...        S  200.0
# 11      0    113783  26.5500  ...        S   35.0
# ...

# %%
     titanic_pclass_data = titanic_data[titanic_data.Pclass==1]

# %%
titanic_pclass1_data.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2       1.0       1
# 3             4       1.0       1
# 6             7       0.0       1
# 11           12       1.0       1
# 23           24       1.0       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 23                       Sloper, Mr. William Thompson    male  28.0      0
#
#     Parch    Ticket     Fare  ... Embarked WikiId  \
# 1       0  PC 17599  71.2833  ...        C   90.0
# 3       0    113803  53.1000  ...        S  127.0
# 6       0     17463  51.8625  ...        S  200.0
# 11      0    113783  26.5500  ...        S   35.0
# ...

# %%
ages = [20,21,22]
age_dataset = titanic_data[titanic_data["Age"].isin(ages)]
age_dataset.head()
# Out:
#     PassengerId  Survived  Pclass                            Name     Sex  \
# 0             1       0.0       3         Braund, Mr. Owen Harris    male
# 12           13       0.0       3  Saundercock, Mr. William Henry    male
# 37           38       0.0       3        Cann, Mr. Ernest Charles    male
# 51           52       0.0       3    Nosworthy, Mr. Richard Cater    male
# 56           57       1.0       2               Rugg, Miss. Emily  female
#
#      Age  SibSp  Parch      Ticket   Fare  ... Embarked  WikiId  \
# 0   22.0      1      0   A/5 21171   7.25  ...        S   691.0
# 12  20.0      0      0   A/5. 2151   8.05  ...        S  1196.0
# 37  21.0      0      0  A./5. 2152   8.05  ...        S   712.0
# 51  21.0      0      0  A/4. 39886   7.80  ...        S  1076.0
# 56  21.0      0      0  C.A. 31026  10.50  ...        S   559.0
#
#                          Name_wiki Age_wiki                       Hometown  \
# ...

# %%
ages = [20,21,22]
age_dataset = titanic_data[titanic_data["Age"].isin(ages) & (titanic_data["Pclass"]==1)]
age_dataset.head()
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 102          103       0.0       1           White, Mr. Richard Frasar
# 151          152       1.0       1   Pears, Mrs. Thomas (Edith Wearne)
# 356          357       1.0       1         Bowerman, Miss. Elsie Edith
# 373          374       0.0       1                 Ringhini, Mr. Sante
# 539          540       1.0       1  Frolicher, Miss. Hedwig Margaritha
#
#         Sex   Age  SibSp  Parch    Ticket      Fare  ... Embarked WikiId  \
# 102    male  21.0      0      1     35281   77.2875  ...        S  309.0
# 151  female  22.0      1      0    113776   66.6000  ...        S  226.0
# 356  female  22.0      0      1    113505   55.0000  ...        S   38.0
# 373    male  22.0      0      0  PC 17760  135.6333  ...        C  312.0
# 539  female  22.0      0      2     13568   49.5000  ...        C  125.0
#
#                                     Name_wiki Age_wiki  \
# ...

# %%
titanic_data_filter=titanic_data.filter(["Name","Sex","Age"])

# %%
titanic_data_filter.head()
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0

# %%
titanic_data_filter=titanic_data.drop(["Name","Sex","Age"], axis = 1)
titanic_data_filter.head()
# Out:
#    PassengerId  Survived  Pclass  SibSp  Parch            Ticket     Fare  \
# 0            1       0.0       3      1      0         A/5 21171   7.2500
# 1            2       1.0       1      1      0          PC 17599  71.2833
# 2            3       1.0       3      0      0  STON/O2. 3101282   7.9250
# 3            4       1.0       1      1      0            113803  53.1000
# 4            5       0.0       3      0      0            373450   8.0500
#
#   Cabin Embarked  WikiId                                   Name_wiki  \
# 0   NaN        S   691.0                     Braund, Mr. Owen Harris
# 1   C85        C    90.0  Cumings, Mrs. Florence Briggs (née Thayer)
# 2   NaN        S   865.0                       Heikkinen, Miss Laina
# 3  C123        S   127.0          Futrelle, Mrs. Lily May (née Peel)
# 4   NaN        S   627.0                    Allen, Mr. William Henry
#
#    Age_wiki                            Hometown      Boarded  \
# ...

# %%
     titanic_pclass1_data = titanic_data[titanic_data.Pclass==1]
     titanic_pclass2_data = titanic_data[titanic_data.Pclass==2]

# %%
final_data = titanic_pclass1_data.append(titanic_pclass2_data, ignore_index = true)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22144\2839679087.py in ?()
# ----> 1 final_data = titanic_pclass1_data.append(titanic_pclass2_data, ignore_index = true)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6289             and name not in self._accessors
#    6290             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6291         ):
#    6292             return self[name]
# -> 6293         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
final_data = pd.concat([titanic_pclass2_data, titanic_pclass1_data])

# %%
diabetes_data = pd.read_csv(r'C:/Users/incor/TFOD/diabetes.csv')

# %%
    diabetes_data.head()

# %%
    diabete_data = diabetes_data[diabetes_data.Outcome==1]

# %%
    diabetes_data.head()

# %%
filter=diabetes_data.filter(["Glucose","BMI","Age"])

# %%
filter.head()

# %%
diabetes_data.sort_values(by=['Glucose'])

# %%
diabetes_data = pd.read_csv(r'C:/Users/incor/TFOD/diabetes.csv')

# %%
diabetes_data.sort_values(by=['Glucose'])

# %%
corr_matrix = diabetes_data.corr()

# %%
plt.imshow(corr_matrix, cmap='hot', vmin=0\
           , vmax=1, extent=[0, 8, 0, 8])

plt.title("Correlation Matrix Of The Dataset")
cbar = plt.colorbar(ticks=[0, 0.5, 1])
 
# Set tick labels
plt.xticks(range(len(corr_matrix.columns)),\
           corr_matrix.columns, rotation=90)
plt.yticks(range(len(corr_matrix.columns)),
           corr_matrix.columns)
 
# Display the plot
plt.show()
